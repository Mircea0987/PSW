# %%
import pandas as pd
import numpy as np
# comentariu

# %%
path = r"C:\Users\cazal\OneDrive\Documents\FACULTATE\ANUL III\Sem 2 ASE\Pachete Software\proiect\PSW\data\student.csv"
df = pd.read_csv(path)

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# study_hours_per_day      0
# sleep_hours              0
# phone_usage_hours        0
# social_media_hours       0
# youtube_hours            0
# gaming_hours             0
# breaks_per_day           0
# coffee_intake_mg         0
# exercise_minutes         0
# assignments_completed    0
# attendance_percentage    0
# stress_level             0
# focus_score              0
# final_grade              0
# productivity_score       0
# dtype: int64
